# %% [markdown]
# <a href="https://colab.research.google.com/github/gerardfp/datamarc/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib
import matplotlib.pylab as plt
import seaborn as sns
import numpy as np
from google.colab import auth
from collections import Counter
import gspread
from gspread_dataframe import set_with_dataframe
from oauth2client.client import GoogleCredentials
from google.colab import drive

# %config InlineBackend.figure_format = 'retina'

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)

auth.authenticate_user()
drive.mount('drive')

gc = gspread.authorize(GoogleCredentials.get_application_default())
worksheet = gc.open('datamarc').sheet1
rows = worksheet.get_all_values()
df = pd.DataFrame.from_records(rows)
df.columns = df.iloc[0]
df = df.iloc[1:]

colors = ['#1f77b4', '#d62728','#2ca02c','#ff7f0e','#9467bd','#8c564b','#e377c2','#7f7f7f','#bcbd22','#17becf']
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).
# 0         ANTIGUEDAD    SEXO  CONTRATO    DEPARTAMENTO COMPROMISO MOTIVACION  \
# 1   Menos de 1 año    Mujer   Temporal  Jurídico        3.67       3.33
# 2   Entre 1 y 5 años  Mujer   Temporal  Administración  3.67       3.33
# 3   Entre 1 y 5 años  Hombre  Otro      Administración  3.67       3.33
# 4   Más de 10 años    Hombre  Fijo      Económico       4.00       4.00
# 5   Menos de 1 año    Mujer   Temporal  Administración  3.67       4.33
# 6   Otro              Hombre  Fijo      Técnico         3.33       3.00
# 7   Menos de 1 año    Mujer   Temporal  Otro            3.00       3.33
# 8   Menos de 1 año    Hombre  Temporal  Administración  4.00       4.33
# 9   Más de 10 años    Mujer   Fijo      Jurídico        3.33       3.67
# 10  Más de 10 años    Mujer   Fijo      Jurídico        4.00       3.00
# 11  Entre 1 y 5 años  Mujer   Fijo      Mantenimiento   3.67       4.00
# 12  Menos de 1 año    Mujer   Temporal  Administración  2.33       2.33
# 13  Más de 5 años     Mujer   Fijo      Técnico         3.00       2.33
# 14  Otro              Mujer   Fijo      Administración  4.00       3.33
# 15  Más de 5 años     Hombre  Fijo      Jurídico        4.33       4.00
# 16  Menos de 1 año    Mujer   Temporal  Económico       5.00       5.00
# 17  Menos de 1 año    Mujer   Temporal  Económico       3.67       3.33
# 18  Menos de 1 año    Hombre  Temporal  Mantenimiento   4.33       4.00
# 19  Menos de 1 año    Hombre  Temporal  Mantenimiento   3.67       3.00
# 20  Más de 10 años    Hombre  Fijo      Mantenimiento   4.00       3.33
# 21  Más de 10 años    Mujer   Fijo      Administración  3.00       3.00
# 22  Más de 10 años    Mujer   Fijo      Económico       3.67       2.67
# 23  Menos de 1 año    Mujer   Temporal  Económico       4.67       4.67
# 24  Más de 10 años    Mujer   Fijo      Económico       3.33       2.33
#
# 0  APRENDIZAJE COMUNICACION PARTICIPACIÓN SEGURIDAD COMPENSACION BIENESTAR  \
# 1   3.00        3.33         3.00          3.33      3.33         4.50
# 2   3.00        3.33         2.33          3.67      3.00         3.50
# 3   2.33        3.67         3.33          4.67      2.67         4.50
# 4   3.33        4.00         3.67          4.00      3.33         4.50
# 5   4.00        4.33         2.67          3.67      2.33         5.00
# 6   2.67        2.67         3.00          3.33      2.33         3.50
# 7   2.00        2.67         2.33          3.33      2.33         4.00
# 8   4.00        4.33         2.67          3.00      2.67         4.00
# 9   3.00        3.33         3.67          3.33      3.00         2.50
# 10  3.00        4.67         2.67          2.67      3.67         3.00
# 11  3.33        3.67         3.67          4.67      3.00         5.00
# 12  2.33        2.33         1.67          3.00      2.33         3.00
# 13  2.00        2.00         3.67          2.33      1.33         2.50
# 14  3.00        3.67         2.67          2.33      1.67         3.00
# 15  3.67        4.67         3.33          4.33      3.00         4.00
# 16  5.00        5.00         4.33          5.00      5.00         5.00
# 17  2.33        3.33         2.00          3.00      2.67         3.00
# 18  3.33        4.00         3.67          4.67      2.67         5.00
# 19  2.67        3.33         2.33          5.00      2.33         4.50
# 20  3.33        4.67         3.67          5.00      3.00         5.00
# 21  2.33        2.33         2.00          2.67      1.67         3.50
# 22  2.33        2.33         2.33          3.33      1.67         4.00
# 23  4.00        5.00         3.00          5.00      2.67         5.00
# 24  2.33        2.33         1.67          2.67      2.00         2.00
#
# 0  GENERO  RRLL
# 1   3.33   3.33
# 2   3.81   3.67
# 3   4.05   4.33
# 4   4.14   4.00
# 5   4.38   4.67
# 6   3.43   3.00
# 7   2.95   2.67
# 8   4.00   4.00
# 9   3.14   3.00
# 10  3.57   4.00
# 11  4.33   4.33
# 12  3.19   2.33
# 13  2.48   1.33
# 14  3.00   3.00
# 15  4.19   4.33
# 16  5.00   5.00
# 17  4.10   3.67
# 18  4.67   4.67
# 19  3.95   3.67
# 20  4.33   4.33
# 21  2.90   2.33
# 22  3.24   2.67
# 23  5.00   5.00
# 24  2.76   2.33

# %%
from textwrap import fill

def make_pair(cat,  bboxy, ncol, bboxx, col_wrap=3, height=2.7, aspect=1.8):

  sns.set_theme(style="whitegrid")
  sns.set_context("talk")
  sns.set_palette(sns.color_palette(colors))

  
  # data = pd.melt(df,id_vars=df.columns[0], value_vars=df.columns[4:])
  data = pd.melt(df,id_vars=cat, value_vars=df.columns[4:])
  data.rename(columns={data.columns[1]: "variable", "value":"valor"}, inplace=True)
  data["valor"] = data["valor"].astype('float')
  # display(data)
  # data.rename(columns={data.columns[1]: "variable", "value":"valor"}, inplace=True)
  # display(data)

  g = sns.FacetGrid(data, col=data.columns[1], hue=data.columns[0], col_wrap=col_wrap, sharex=False, sharey=False, aspect=aspect, height=height)
  g.map(sns.kdeplot, "valor")
  # #g.add_legend(loc="lower left", ncol=5, title=" ", fontsize=16, bbox_to_anchor=(0.025,0.8,1,1)) # prop={'size': 10})
  g.add_legend(loc='upper center',  ncol=ncol, bbox_to_anchor=(bboxx, bboxy), frameon=False,handlelength=1)
  for text in g.legend.get_texts():
    text.set_text(fill(text.get_text(), 20))
  for legobj in g.legend.get_lines():
    legobj.set_linewidth(4)

  g.set_xlabels("")
  g.fig.set_dpi(150)
  g.set_titles("{col_name}")

make_pair('SEXO', bboxy=1.1, ncol=4, bboxx=0.25)
